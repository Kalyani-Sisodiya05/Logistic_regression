# %% [markdown]
# ![log1.PNG](attachment:log1.PNG)

# %% [markdown]
# ![log2.PNG](attachment:log2.PNG)

# %% [markdown]
# ![log3.PNG](attachment:log3.PNG)

# %% [markdown]
# ![log4.PNG](attachment:log4.PNG)

# %% [markdown]
# ![log5.PNG](attachment:log5.PNG)

# %% [markdown]
# ![log6.PNG](attachment:log6.PNG)

# %% [markdown]
# ![log7.PNG](attachment:log7.PNG)
